# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahroyle/SDA-Group-Work/blob/main/SDA_Group_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sarah's Work :)

# %%
# Investigating edad, angulo, clase ad protrustion

import numpy as np
# Import plotting and dataframe packages
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

df = pd.read_excel(io='https://github.com/MMRES-PyBootcamp/MMRES-python-bootcamp2022/blob/main/datasets/misophoinia_data.xlsx?raw=true')

# Return the Misophoinia DataFrame
df
# Out:
#     Misofonia  Misofonia.dic      Estado  Estado.dic  ansiedad.rasgo  \
# 0          si            4.0  divorciado         2.0            99.0
# 1          si            2.0      casado         1.0            75.0
# 2          no            0.0  divorciado         2.0            77.0
# 3          si            3.0      casado         1.0            95.0
# 4          no            0.0      casado         1.0            30.0
# ..        ...            ...         ...         ...             ...
# 133       NaN            NaN         NaN         NaN             NaN
# 134       NaN            NaN         NaN         NaN             NaN
# 135       NaN            NaN         NaN         NaN             NaN
# 136       NaN            NaN         NaN         NaN             NaN
# 137       NaN            NaN         NaN         NaN             NaN
#
#      ansiedad.rasgo.dic  ansiedad.estado  ansiedad.estado.dic  \
# 0                   1.0             99.0                  1.0
# ...

# %%
list_drop = ['Estado', 'Estado.dic', 'ansiedad.rasgo', 'ansiedad.rasgo.dic', 'ansiedad.estado', 'ansiedad.estado.dic', 'ansiedad.medicada', 'ansiedad.medicada.dic']
df = df.drop(columns=list_drop)

list_drop = ['depresion', 'depresion.dic']
df = df.drop(columns=list_drop)

list_drop = ['cambio.autoconcepto', 'Misofonia.post', 'Misofonia.pre', 'ansiedad.dif']
df = df.drop(columns=list_drop)

# Return the Reduced DataFrame
df
# Out:
#     Misofonia  Misofonia.dic Sexo  Edad CLASE  Angulo_convexidad  \
# 0          si            4.0    M  44.0   III               7.97
# 1          si            2.0    M  43.0    II              18.23
# 2          no            0.0    M  24.0     I              12.27
# 3          si            3.0    M  33.0   III               7.81
# 4          no            0.0    H  41.0     I               9.81
# ..        ...            ...  ...   ...   ...                ...
# 133       NaN            NaN  NaN   NaN   NaN                NaN
# 134       NaN            NaN  NaN   NaN   NaN                NaN
# 135       NaN            NaN  NaN   NaN   NaN                NaN
# 136       NaN            NaN  NaN   NaN   NaN                NaN
# 137       NaN            NaN  NaN   NaN   NaN                NaN
#
#      protusion.mandibular  Angulo_cuelloYtercio  Subnasal_H
# 0                    13.0                  89.6         1.5
# 1                    -5.0                 107.2         7.3
# ...

# %%
df.head()
# Out:
#   Misofonia  Misofonia.dic Sexo  Edad CLASE  Angulo_convexidad  \
# 0        si            4.0    M  44.0   III               7.97
# 1        si            2.0    M  43.0    II              18.23
# 2        no            0.0    M  24.0     I              12.27
# 3        si            3.0    M  33.0   III               7.81
# 4        no            0.0    H  41.0     I               9.81
#
#    protusion.mandibular  Angulo_cuelloYtercio  Subnasal_H
# 0                  13.0                  89.6         1.5
# 1                  -5.0                 107.2         7.3
# 2                  11.5                 101.4         5.0
# 3                  16.8                  75.3         2.7
# 4                  33.0                 105.5         6.0

# %%
df.tail()
# Out:
#     Misofonia  Misofonia.dic Sexo  Edad CLASE  Angulo_convexidad  \
# 133       NaN            NaN  NaN   NaN   NaN                NaN
# 134       NaN            NaN  NaN   NaN   NaN                NaN
# 135       NaN            NaN  NaN   NaN   NaN                NaN
# 136       NaN            NaN  NaN   NaN   NaN                NaN
# 137       NaN            NaN  NaN   NaN   NaN                NaN
#
#      protusion.mandibular  Angulo_cuelloYtercio  Subnasal_H
# 133                   NaN                   NaN         NaN
# 134                   NaN                   NaN         NaN
# 135                   NaN                   NaN         NaN
# 136                   NaN                   NaN         NaN
# 137                   NaN                   NaN         NaN

# %%
print(Counter(df['Sexo']))
df.groupby('Sexo').size()

df['Sexo'].value_counts(normalize=True) * 100
fig, ax = plt.subplots()
ax.bar([0,1],df['Sexo'].value_counts(normalize=True) * 100)
ax.set_xticks([0,1])
ax.set_xticklabels(['H','M'])
ax.set_ylabel('Percentage')
# Out:
# Counter({'M': 78, 'H': 45, nan: 15})
# Text(0, 0.5, 'Percentage')

# %%
df['Sexo'].describe()
# Out:
# count     123
# unique      2
# top         M
# freq       78
# Name: Sexo, dtype: object

# %%
df['Edad'].describe()
# Out:
# count    123.000000
# mean      43.934959
# std       14.186544
# min       13.000000
# 25%       34.000000
# 50%       43.000000
# 75%       53.000000
# max       86.000000
# Name: Edad, dtype: float64

# %%
df['Misofonia'].describe()
# Out:
# count     123
# unique      2
# top        si
# freq       82
# Name: Misofonia, dtype: object

# %%
df['Misofonia.dic'].describe()
# Out:
# count    123.000000
# mean       1.691057
# std        1.355802
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: Misofonia.dic, dtype: float64

# %%
df['CLASE'].describe()
# Out:
# count     123
# unique      3
# top       III
# freq       69
# Name: CLASE, dtype: object

# %%
df['Angulo_convexidad'].describe()
# Out:
# count    123.000000
# mean      10.198943
# std        5.086707
# min       -1.000000
# 25%        7.020000
# 50%        7.960000
# 75%       14.225000
# max       21.300000
# Name: Angulo_convexidad, dtype: float64

# %%
df['protusion.mandibular'].describe()
# Out:
# count    123.000000
# mean      13.328049
# std       16.739341
# min      -30.000000
# 25%        3.650000
# 50%       12.200000
# 75%       21.700000
# max       92.000000
# Name: protusion.mandibular, dtype: float64

# %%
df['Angulo_cuelloYtercio'].describe()
# Out:
# count    123.000000
# mean      93.722764
# std       12.211918
# min       56.000000
# 25%       84.950000
# 50%       92.000000
# 75%      105.150000
# max      119.000000
# Name: Angulo_cuelloYtercio, dtype: float64

# %%
df['Subnasal_H'].describe()
# Out:
# count    123.000000
# mean       3.563659
# std        3.217642
# min       -6.700000
# 25%        2.200000
# 50%        2.900000
# 75%        6.300000
# max        9.800000
# Name: Subnasal_H, dtype: float64

# %%
# Get countplot of edad vs misofonia score
ax = sns.countplot(data=df, x='Sexo')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# %%
# Get countplot of edad vs misofonia score
ax = sns.countplot(data=df, x='CLASE', hue = 'Sexo')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# %%
# Get countplot of edad vs misofonia score
ax = sns.countplot(data=df, x='Misofonia.dic')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# %%
# Get countplot of edad vs misofonia score
ax = sns.countplot(data=df, x='Misofonia.dic', hue = 'CLASE')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# %%
# Get countplot of edad vs misofonia score
ax = sns.countplot(data=df, x='Misofonia.dic', hue = 'Sexo')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# %%
# Group by 'Edad' and aggregate with mean
df_edad = df.groupby(by=['Edad'])[['Misofonia.dic']].mean()

# Return the DataFrame
df_edad
# Out:
#       Misofonia.dic
# Edad
# 13.0       2.000000
# 19.0       1.250000
# 21.0       2.000000
# 22.0       1.500000
# 24.0       0.000000
# 25.0       1.500000
# 26.0       0.000000
# 27.0       3.000000
# 28.0       1.000000
# 31.0       1.000000
# 32.0       2.000000
# 33.0       1.857143
# 34.0       1.400000
# 35.0       1.166667
# 36.0       2.000000
# 37.0       3.000000
# 38.0       3.333333
# 39.0       2.500000
# 40.0       0.666667
# 41.0       1.142857
# 42.0       1.000000
# 43.0       2.333333
# 44.0       2.600000
# 45.0       1.750000
# 47.0       2.500000
# 48.0       3.250000
# 49.0       3.000000
# 50.0       2.000000
# 51.0       0.000000
# 52.0       2.400000
# 53.0       2.000000
# 54.0       2.000000
# 55.0       2.000000
# 57.0       2.500000
# 58.0       1.500000
# 59.0       1.250000
# 60.0       1.000000
# 62.0       0.000000
# 64.0       0.000000
# 65.0       0.000000
# 67.0       0.000000
# 69.0       1.333333
# 71.0       2.000000
# 74.0       0.000000
# ...

# %%
# Get histplot
ax = sns.histplot(data=df_edad, x='Edad')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# NOTE graph shows number of people with ages in the study

# %%
sns.scatterplot(data=df, x='Misofonia.dic', y='Edad')
# Raw data

# %%
sns.boxplot(data=df, x='Misofonia.dic', y='Edad')

# %%
sns.scatterplot(data=df_edad, x='Edad', y='Misofonia.dic')
# plot for mean misophonia scores per age

# %%
sns.scatterplot(data=df, x='CLASE', y='Angulo_convexidad')
# Raw data

# %%
sns.boxplot(data=df, x='CLASE', y='Angulo_convexidad')

# %%
sns.scatterplot(data=df, x='CLASE', y='protusion.mandibular')
# Raw data

# %%
sns.boxplot(data=df, x='CLASE', y='protusion.mandibular')

# %%
sns.scatterplot(data=df, x='Misofonia.dic', y='protusion.mandibular')
# Raw data

# %%
sns.scatterplot(data=df, x='Misofonia.dic', y='Angulo_convexidad')
# Raw data

# %%
sns.boxplot(data=df, x='Misofonia.dic', y='Angulo_convexidad')

# %%
sns.violinplot(data=df, x='Misofonia.dic', y='Angulo_convexidad')

# %%
sns.histplot(data=df, x='Sexo', hue='Misofonia', alpha=1, multiple="stack")

# %%
sns.violinplot(data=df, x='Sexo', y='Misofonia.dic')

# %%
# I need to some stats and normalisation of the data

# %%
x_mean = np.mean()

# Return "x_mean"
print(x_mean)

# %%
# play with plotting packages

# Then need to move onto hypothesis testing

# %% [markdown]
# # Cristina's Work :)

# %%
# Describe the participants’ sex, marital status, ansiety status, and state of depression
import numpy as np
# Import plotting and dataframe packages
import seaborn as sns
import pandas as pd

df = pd.read_excel(io='https://github.com/MMRES-PyBootcamp/MMRES-python-bootcamp2022/blob/main/datasets/misophoinia_data.xlsx?raw=true')

# Return the Misophoinia DataFrame
df
# Out:
#     Misofonia  Misofonia.dic      Estado  Estado.dic  ansiedad.rasgo  \
# 0          si            4.0  divorciado         2.0            99.0
# 1          si            2.0      casado         1.0            75.0
# 2          no            0.0  divorciado         2.0            77.0
# 3          si            3.0      casado         1.0            95.0
# 4          no            0.0      casado         1.0            30.0
# ..        ...            ...         ...         ...             ...
# 133       NaN            NaN         NaN         NaN             NaN
# 134       NaN            NaN         NaN         NaN             NaN
# 135       NaN            NaN         NaN         NaN             NaN
# 136       NaN            NaN         NaN         NaN             NaN
# 137       NaN            NaN         NaN         NaN             NaN
#
#      ansiedad.rasgo.dic  ansiedad.estado  ansiedad.estado.dic  \
# 0                   1.0             99.0                  1.0
# ...

# %%
list_drop = ['ansiedad.rasgo', 'ansiedad.rasgo.dic', 'ansiedad.medicada', 'ansiedad.medicada.dic', 'CLASE']
df = df.drop(columns=list_drop)

list_drop = ['Angulo_convexidad', 'protusion.mandibular',	'Angulo_cuelloYtercio',	'Subnasal_H']
df = df.drop(columns=list_drop)

list_drop = ['cambio.autoconcepto', 'Misofonia.post', 'Misofonia.pre']
df = df.drop(columns=list_drop)

# Return the Reduced DataFrame
df
# Out:
#     Misofonia  Misofonia.dic      Estado  Estado.dic  ansiedad.estado  \
# 0          si            4.0  divorciado         2.0             99.0
# 1          si            2.0      casado         1.0             75.0
# 2          no            0.0  divorciado         2.0             55.0
# 3          si            3.0      casado         1.0             99.0
# 4          no            0.0      casado         1.0             40.0
# ..        ...            ...         ...         ...              ...
# 133       NaN            NaN         NaN         NaN              NaN
# 134       NaN            NaN         NaN         NaN              NaN
# 135       NaN            NaN         NaN         NaN              NaN
# 136       NaN            NaN         NaN         NaN              NaN
# 137       NaN            NaN         NaN         NaN              NaN
#
#      ansiedad.estado.dic  depresion  depresion.dic Sexo  Edad  ansiedad.dif
# ...

# %%
df.head()
# Out:
#   Misofonia  Misofonia.dic      Estado  Estado.dic  ansiedad.estado  \
# 0        si            4.0  divorciado         2.0             99.0
# 1        si            2.0      casado         1.0             75.0
# 2        no            0.0  divorciado         2.0             55.0
# 3        si            3.0      casado         1.0             99.0
# 4        no            0.0      casado         1.0             40.0
#
#    ansiedad.estado.dic  depresion  depresion.dic Sexo  Edad  ansiedad.dif
# 0                  1.0      33.65            1.0    M  44.0           0.0
# 1                  1.0      19.77            0.0    M  43.0           0.0
# 2                  0.0      29.57            0.0    M  24.0         -22.0
# 3                  1.0       1.40            0.0    M  33.0           4.0
# 4                  0.0       5.98            0.0    H  41.0          10.0

# %%
df.tail()
# Out:
#     Misofonia  Misofonia.dic Estado  Estado.dic  ansiedad.estado  \
# 133       NaN            NaN    NaN         NaN              NaN
# 134       NaN            NaN    NaN         NaN              NaN
# 135       NaN            NaN    NaN         NaN              NaN
# 136       NaN            NaN    NaN         NaN              NaN
# 137       NaN            NaN    NaN         NaN              NaN
#
#      ansiedad.estado.dic  depresion  depresion.dic Sexo  Edad  ansiedad.dif
# 133                  NaN        NaN            NaN  NaN   NaN           NaN
# 134                  NaN        NaN            NaN  NaN   NaN           NaN
# 135                  NaN        NaN            NaN  NaN   NaN           NaN
# 136                  NaN        NaN            NaN  NaN   NaN           NaN
# 137                  NaN        NaN            NaN  NaN   NaN           NaN

# %%
# DataFrame (basic) statistical description (only for numeric columns!)
df.describe()
# Out:
#        Misofonia.dic  Estado.dic  ansiedad.estado  ansiedad.estado.dic  \
# count     123.000000  123.000000       123.000000           123.000000
# mean        1.691057    1.040650        67.853659             0.666667
# std         1.355802    0.761775        29.664706             0.473333
# min         0.000000    0.000000         1.000000             0.000000
# 25%         0.000000    1.000000        45.000000             0.000000
# 50%         2.000000    1.000000        77.000000             1.000000
# 75%         3.000000    1.000000        90.000000             1.000000
# max         4.000000    3.000000        99.000000             1.000000
#
#         depresion  depresion.dic        Edad  ansiedad.dif
# count  123.000000     123.000000  123.000000    123.000000
# mean    17.856179       0.186992   43.934959     -0.918699
# std     11.738407       0.391500   14.186544     12.866014
# min      0.250000       0.000000   13.000000    -45.000000
# ...

# %%
# DataFrame general information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Misofonia            123 non-null    object
#  1   Misofonia.dic        123 non-null    float64
#  2   Estado               123 non-null    object
#  3   Estado.dic           123 non-null    float64
#  4   ansiedad.estado      123 non-null    float64
#  5   ansiedad.estado.dic  123 non-null    float64
#  6   depresion            123 non-null    float64
#  7   depresion.dic        123 non-null    float64
#  8   Sexo                 123 non-null    object
#  9   Edad                 123 non-null    float64
#  10  ansiedad.dif         123 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 12.0+ KB

# %%
# Get countplot of sex vs misofonia score
ax = sns.countplot(data=df, x='Sexo')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# %%
# Get countplot of sex vs misofonia score
ax = sns.countplot(data=df, y='Estado')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# %%
# Get countplot of edad vs misofonia score
ax = sns.countplot(data=df, x='ansiedad.estado')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# %%
# Group by 'Edad' and aggregate with mean
df_status = df.groupby(by=['Edad'])[['ansiedad.estado']].mean()

# Return the DataFrame
df_status
# Out:
#       ansiedad.estado
# Edad
# 13.0        30.000000
# 19.0        66.250000
# 21.0        84.500000
# 22.0        76.000000
# 24.0        55.000000
# 25.0        65.000000
# 26.0        20.000000
# 27.0        99.000000
# 28.0        30.000000
# 31.0        54.250000
# 32.0        69.250000
# 33.0        76.571429
# 34.0        64.600000
# 35.0        55.666667
# 36.0        70.000000
# 37.0        77.000000
# 38.0        92.000000
# 39.0        76.000000
# 40.0        64.000000
# 41.0        55.428571
# 42.0        71.000000
# 43.0        87.333333
# 44.0        74.800000
# 45.0        70.500000
# 47.0        86.000000
# 48.0        89.500000
# 49.0        97.000000
# 50.0        65.000000
# 51.0        35.000000
# 52.0        85.200000
# 53.0        85.750000
# 54.0        80.000000
# 55.0        61.400000
# 57.0        83.500000
# 58.0        65.000000
# 59.0        65.750000
# 60.0        53.500000
# 62.0        57.500000
# 64.0         1.000000
# 65.0        97.000000
# ...

# %%
# Get histplot
ax = sns.histplot(data=df_status, x='ansiedad.estado')

# Rotate xlabels 90 degrees
ax.tick_params(axis='x', rotation=90)

# NOTE graph shows number of people with ages in the study

# %%
sns.violinplot(data=df, x='Misofonia.dic', y='ansiedad.estado')

# %%
sns.scatterplot(data=df, x='Edad', y='depresion')
# Raw data

# %%
sns.boxplot(data=df, x='Sexo', y='depresion')

# %%
df1 = pd.read_excel(io='https://github.com/MMRES-PyBootcamp/MMRES-python-bootcamp2022/blob/main/datasets/misophoinia_data.xlsx?raw=true')

# Return the Misophoinia DataFrame
df1
# Out:
#     Misofonia  Misofonia.dic      Estado  Estado.dic  ansiedad.rasgo  \
# 0          si            4.0  divorciado         2.0            99.0
# 1          si            2.0      casado         1.0            75.0
# 2          no            0.0  divorciado         2.0            77.0
# 3          si            3.0      casado         1.0            95.0
# 4          no            0.0      casado         1.0            30.0
# ..        ...            ...         ...         ...             ...
# 133       NaN            NaN         NaN         NaN             NaN
# 134       NaN            NaN         NaN         NaN             NaN
# 135       NaN            NaN         NaN         NaN             NaN
# 136       NaN            NaN         NaN         NaN             NaN
# 137       NaN            NaN         NaN         NaN             NaN
#
#      ansiedad.rasgo.dic  ansiedad.estado  ansiedad.estado.dic  \
# 0                   1.0             99.0                  1.0
# ...

# %%
list_drop1 = ['Misofonia.dic', 'Estado.dic', 'ansiedad.dif', 'ansiedad.rasgo', 'ansiedad.medicada',	'ansiedad.medicada.dic']
df1 = df1.drop(columns=list_drop1)

list_drop1 = ['CLASE',	'Angulo_convexidad', 'protusion.mandibular',	'Angulo_cuelloYtercio',	'Subnasal_H',	'cambio.autoconcepto',	'Misofonia.post' ]
df1 = df1.drop(columns=list_drop1)

list_drop1 = ['Estado', 'ansiedad.rasgo.dic', 'Misofonia.pre', 'Edad', 'ansiedad.estado.dic', 'depresion.dic']
df1 = df1.drop(columns=list_drop1)
# Return the Reduced DataFrame
df1
# Out:
#     Misofonia  ansiedad.estado  depresion Sexo
# 0          si             99.0      33.65    M
# 1          si             75.0      19.77    M
# 2          no             55.0      29.57    M
# 3          si             99.0       1.40    M
# 4          no             40.0       5.98    H
# ..        ...              ...        ...  ...
# 133       NaN              NaN        NaN  NaN
# 134       NaN              NaN        NaN  NaN
# 135       NaN              NaN        NaN  NaN
# 136       NaN              NaN        NaN  NaN
# 137       NaN              NaN        NaN  NaN
#
# [138 rows x 4 columns]

# %%
# Accessing DataFrame columns
df1[['Misofonia',	'ansiedad.estado',	'depresion',	'Sexo']]
# Out:
#     Misofonia  ansiedad.estado  depresion Sexo
# 0          si             99.0      33.65    M
# 1          si             75.0      19.77    M
# 2          no             55.0      29.57    M
# 3          si             99.0       1.40    M
# 4          no             40.0       5.98    H
# ..        ...              ...        ...  ...
# 133       NaN              NaN        NaN  NaN
# 134       NaN              NaN        NaN  NaN
# 135       NaN              NaN        NaN  NaN
# 136       NaN              NaN        NaN  NaN
# 137       NaN              NaN        NaN  NaN
#
# [138 rows x 4 columns]

# %%
# DataFrame line plot
df1.plot.line()

# %% [markdown]
# # Sección nueva
